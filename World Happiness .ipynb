# %% [markdown]
# <h1><center>World Happiness Report</center></h1

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)import seaborn as sns
import matplotlib.pyplot as plt
import seaborn as sns
import geopandas as gpd

# %% [markdown]
# ## Data Preperation and Cleaning

# %%
df1 = pd.read_csv("world-happiness-report.csv")
df2 = pd.read_csv("world-happiness-report-2021-complete-info.csv")
world = gpd.read_file(gpd.datasets.get_path('naturalearth_lowres'))

# %%
df1
# Out:
#      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# ...

# %%
df2
# Out:
#     Country name  Regional indicator  Ladder score  \
# 0        Finland      Western Europe         7.842
# 1        Denmark      Western Europe         7.620
# 2    Switzerland      Western Europe         7.571
# 3        Iceland      Western Europe         7.554
# 4    Netherlands      Western Europe         7.464
# ..           ...                 ...           ...
# 144      Lesotho  Sub-Saharan Africa         3.512
# 145     Botswana  Sub-Saharan Africa         3.467
# 146       Rwanda  Sub-Saharan Africa         3.415
# 147     Zimbabwe  Sub-Saharan Africa         3.145
# 148  Afghanistan          South Asia         2.523
#
#      Standard error of ladder score  upperwhisker  lowerwhisker  \
# 0                             0.032         7.904         7.780
# 1                             0.035         7.687         7.552
# 2                             0.036         7.643         7.500
# 3                             0.059         7.670         7.438
# ...

# %%
df1.columns
# Out:
# Index(['Country name', 'year', 'Life Ladder', 'Log GDP per capita',
#        'Social support', 'Healthy life expectancy at birth',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Positive affect', 'Negative affect'],
#       dtype='object')

# %%
df2.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
len(df1.columns)
# Out:
# 11

# %%
len(df2.columns)
# Out:
# 20

# %%
df1.info
# Out:
# <bound method DataFrame.info of      Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 0     Afghanistan  2008        3.724               7.370           0.451
# 1     Afghanistan  2009        4.402               7.540           0.552
# 2     Afghanistan  2010        4.758               7.647           0.539
# 3     Afghanistan  2011        3.832               7.620           0.521
# 4     Afghanistan  2012        3.783               7.705           0.521
# ...           ...   ...          ...                 ...             ...
# 1944     Zimbabwe  2016        3.735               7.984           0.768
# 1945     Zimbabwe  2017        3.638               8.016           0.754
# 1946     Zimbabwe  2018        3.616               8.049           0.775
# 1947     Zimbabwe  2019        2.694               7.950           0.759
# 1948     Zimbabwe  2020        3.160               7.829           0.717
#
# ...

# %%
df1.describe()
# Out:
#               year  Life Ladder  Log GDP per capita  Social support  \
# count  1949.000000  1949.000000         1913.000000     1936.000000
# mean   2013.216008     5.466705            9.368453        0.812552
# std       4.166828     1.115711            1.154084        0.118482
# min    2005.000000     2.375000            6.635000        0.290000
# 25%    2010.000000     4.640000            8.464000        0.749750
# 50%    2013.000000     5.386000            9.460000        0.835500
# 75%    2017.000000     6.283000           10.353000        0.905000
# max    2020.000000     8.019000           11.648000        0.987000
#
#        Healthy life expectancy at birth  Freedom to make life choices  \
# count                       1894.000000                   1917.000000
# mean                          63.359374                      0.742558
# std                            7.510245                      0.142093
# min                           32.300000                      0.258000
# ...

# %%
df2.describe()
# Out:
#        Ladder score  Standard error of ladder score  upperwhisker  \
# count    149.000000                      149.000000    149.000000
# mean       5.532839                        0.058752      5.648007
# std        1.073924                        0.022001      1.054330
# min        2.523000                        0.026000      2.596000
# 25%        4.852000                        0.043000      4.991000
# 50%        5.534000                        0.054000      5.625000
# 75%        6.255000                        0.070000      6.344000
# max        7.842000                        0.173000      7.904000
#
#        lowerwhisker  Logged GDP per capita  Social support  \
# count    149.000000             149.000000      149.000000
# mean       5.417631               9.432208        0.814745
# std        1.094879               1.158601        0.114889
# min        2.449000               6.635000        0.463000
# 25%        4.706000               8.541000        0.750000
# ...

# %%
## How much numeric data do we have to work with

numerics = ['int16','int32','int64', 'float16','float32','float64']

df1 = df1.select_dtypes(include=numerics)

len(df1.columns)
# Out:
# 10

# %%
## PERCENTAGE OF MISSING VALUES PER COLUMN
## Finding missing values
## if the data has a value it will say false with df.isna(). With df.isna.sum() we get missing values per column 
missing_percentages = df1.isna().sum().sort_values(ascending=False) / len(df1)
missing_percentages
# Out:
# Perceptions of corruption           0.056439
# Generosity                          0.045664
# Healthy life expectancy at birth    0.028220
# Log GDP per capita                  0.018471
# Freedom to make life choices        0.016419
# Positive affect                     0.011288
# Negative affect                     0.008209
# Social support                      0.006670
# Life Ladder                         0.000000
# year                                0.000000
# dtype: float64

# %%
# No missing data for df2
missing_percentages = df1.isna().sum().sort_values(ascending=False) / len(df1)
missing_percentages
# Out:
# Perceptions of corruption           0.056439
# Generosity                          0.045664
# Healthy life expectancy at birth    0.028220
# Log GDP per capita                  0.018471
# Freedom to make life choices        0.016419
# Positive affect                     0.011288
# Negative affect                     0.008209
# Social support                      0.006670
# Life Ladder                         0.000000
# year                                0.000000
# dtype: float64

# %%
## if the data says true = there is a zero. if it says false = there is no zero. you can use this meathod to shorten the data so its easier to read and there are no useless datas involved. 
missing_percentages[missing_percentages != 0]
# Out:
# Perceptions of corruption           0.056439
# Generosity                          0.045664
# Healthy life expectancy at birth    0.028220
# Log GDP per capita                  0.018471
# Freedom to make life choices        0.016419
# Positive affect                     0.011288
# Negative affect                     0.008209
# Social support                      0.006670
# dtype: float64

# %%
type(missing_percentages)
# Out:
# pandas.core.series.Series

# %%
missing_percentages.plot(kind='barh')

# %%
low_c = '#dd4124'
high_c = '#009473'
plt.rcParams["font.family"] = "monospace"



fig = plt.figure(figsize=(6,3),dpi=150)
gs = fig.add_gridspec(1, 1)
gs.update(wspace=0.2, hspace=0.4)
ax0 = fig.add_subplot(gs[0, 0])

background_color = "#fafafa"
fig.patch.set_facecolor(background_color) # figure background color
ax0.set_facecolor(background_color) 

ax0.text(1.167,0.85,"2021 World Happiness Index",color='#323232',fontsize=28, fontweight='bold', fontfamily='sanserif',ha='center')
ax0.text(1.13,-0.35,"stand-out facts",color='lightgray',fontsize=28, fontweight='bold', fontfamily='monospace',ha='center')

ax0.text(0,0.4,"Finland",color=high_c,fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(0,0.1,"Happiest",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.text(0.77,0.4,"9 of top 10",color=high_c,fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(0.75,0.1,"in Europe",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.text(1.5,0.4,"7 of bottom 10",color=low_c,fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(1.5,0.1,"in Africa",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.text(2.25,0.4,"Afghanistan",color=low_c,fontsize=25, fontweight='bold', fontfamily='monospace',ha='center')
ax0.text(2.25,0.1,"Unhappiest",color='gray',fontsize=15, fontfamily='monospace',ha='center')

ax0.set_yticklabels('')
ax0.set_xticklabels('')
ax0.tick_params(axis='both',length=0)

for s in ['top','right','left','bottom']:
    ax0.spines[s].set_visible(False)
    
import matplotlib.lines as lines
l1 = lines.Line2D([0.15, 1.95], [0.67, 0.67], transform=fig.transFigure, figure=fig,color = 'gray', linestyle='-',linewidth = 1.1, alpha = .5)
fig.lines.extend([l1])
l2 = lines.Line2D([0.15, 1.95], [0.07, 0.07], transform=fig.transFigure, figure=fig,color = 'gray', linestyle='-',linewidth = 1.1, alpha = .5)
fig.lines.extend([l2])
    
plt.show()
# Out:
# findfont: Font family ['sanserif'] not found. Falling back to DejaVu Sans.

# %% [markdown]
# ## Exploratory Analysis and Questions

# %%
## EXPLORATORY ANALYSIS
## Questions to ask for exploratory analysis: 
## Which country is the most happiest?
## Which country is the least Happiest?
## Which country is the happiest based on capita?
## Which factors most effects happiness?
## Which factors least contribute to happiness?

# %%
df2.columns
# Out:
# Index(['Country name', 'Regional indicator', 'Ladder score',
#        'Standard error of ladder score', 'upperwhisker', 'lowerwhisker',
#        'Logged GDP per capita', 'Social support', 'Healthy life expectancy',
#        'Freedom to make life choices', 'Generosity',
#        'Perceptions of corruption', 'Ladder score in Dystopia',
#        'Explained by: Log GDP per capita', 'Explained by: Social support',
#        'Explained by: Healthy life expectancy',
#        'Explained by: Freedom to make life choices',
#        'Explained by: Generosity', 'Explained by: Perceptions of corruption',
#        'Dystopia + residual'],
#       dtype='object')

# %%
df2['Ladder score']
# Out:
# 0      7.842
# 1      7.620
# 2      7.571
# 3      7.554
# 4      7.464
#        ...
# 144    3.512
# 145    3.467
# 146    3.415
# 147    3.145
# 148    2.523
# Name: Ladder score, Length: 149, dtype: float64

# %%
## Variables I will need
Ladder_Hap = df2['Ladder score'][:10]
Ladder_Unhap = df2['Ladder score'].tail(10).sort_values(ascending = True)
Hap= df2['Country name'][:10]
Unhap = df2['Country name'].tail(10)
hap_unhap = Hap.append(Unhap)
top_10_hap = df2.loc[:10, ['Country name','Ladder score']]
Column_names = ['Country name','Ladder score']
top_10_unhap = df2.loc[:, Column_names].tail(10)
top_bottom_10 = top_10_hap.append(top_10_unhap)

# %%
top_bottom_10
# Out:
#     Country name  Ladder score
# 0        Finland         7.842
# 1        Denmark         7.620
# 2    Switzerland         7.571
# 3        Iceland         7.554
# 4    Netherlands         7.464
# 5         Norway         7.392
# 6         Sweden         7.363
# 7     Luxembourg         7.324
# 8    New Zealand         7.277
# 9        Austria         7.268
# 10     Australia         7.183
# 139      Burundi         3.775
# 140        Yemen         3.658
# 141     Tanzania         3.623
# 142        Haiti         3.615
# 143       Malawi         3.600
# 144      Lesotho         3.512
# 145     Botswana         3.467
# 146       Rwanda         3.415
# 147     Zimbabwe         3.145
# 148  Afghanistan         2.523

# %%
world['df2'] = df2['Ladder score']

plt.rcParams['figure.figsize'] = (16,8)

world.plot(column='df2',legend = True)
# Out:
# C:\Users\Shahzaib\Anaconda3\lib\site-packages\matplotlib\colors.py:527: RuntimeWarning: invalid value encountered in less
#   xa[xa < 0] = -1

# %%
data = top_bottom_10


data['colors'] = ['red' if x < 5 else 'green' for x in data['Ladder score']]
data.sort_values('Ladder score', inplace=True)
data.reset_index(inplace=True)


plt.figure(figsize=(14,10), dpi= 80)
plt.hlines(y=data['Country name'], xmin=0, xmax=data['Ladder score'], color=data.colors, alpha=0.4, linewidth=5)

# Decorations
plt.gca().set(ylabel='Country name', xlabel='Ladder score')
plt.yticks(data['Country name'], fontsize=12)
plt.title('Top 10 Happiest and Unhappiest Countries', fontdict={'size':20})
plt.grid(linestyle='--', alpha=0.5)
plt.show()

# %% [markdown]
# Finland seems to be the happiest country compared to the ladder scroes of each country

# %%
df2_factors_hap = df2[:10].groupby('Country name').sum()[['Social support','Freedom to make life choices','Generosity','Perceptions of corruption']]
df2_factors_hap
# Out:
#               Social support  Freedom to make life choices  Generosity  \
# Country name
# Austria                0.934                         0.908       0.042
# Denmark                0.954                         0.946       0.030
# Finland                0.954                         0.949      -0.098
# Iceland                0.983                         0.955       0.160
# Luxembourg             0.908                         0.907      -0.034
# Netherlands            0.942                         0.913       0.175
# New Zealand            0.948                         0.929       0.134
# Norway                 0.954                         0.960       0.093
# Sweden                 0.934                         0.945       0.086
# Switzerland            0.942                         0.919       0.025
#
#               Perceptions of corruption
# Country name
# Austria                           0.481
# Denmark                           0.179
# ...

# %%
# What contributes most to a Country being Happy?
# Not using healthy life expectancy with this analysis because data looks skewed because of the age is a large number

df2_grouped = df2.groupby('Country name').sum()[['Ladder score','Social support','Freedom to make life choices','Generosity','Perceptions of corruption','Ladder score in Dystopia']]

df2_inorder_hap = df2_grouped.sort_values(by = 'Ladder score', ascending = False)[:10]

df2_inorder_hap
# Out:
#               Ladder score  Social support  Freedom to make life choices  \
# Country name
# Finland              7.842           0.954                         0.949
# Denmark              7.620           0.954                         0.946
# Switzerland          7.571           0.942                         0.919
# Iceland              7.554           0.983                         0.955
# Netherlands          7.464           0.942                         0.913
# Norway               7.392           0.954                         0.960
# Sweden               7.363           0.934                         0.945
# Luxembourg           7.324           0.908                         0.907
# New Zealand          7.277           0.948                         0.929
# Austria              7.268           0.934                         0.908
#
#               Generosity  Perceptions of corruption  Ladder score in Dystopia
# Country name
# ...

# %%
sns.heatmap(df2_factors_hap, cmap="gnuplot2")
plt.show()

# %% [markdown]
# We can see in this that geneoristy did not play a huge role in a country being happier

# %%
df2_factors_hap.plot(kind='bar', fontsize = 20)
plt.title('Factors that contribute to Happiness',fontsize = 22)
plt.legend(loc="upper right", bbox_to_anchor=(1.8, 1.03), ncol=2, fontsize = 20)
plt.ylabel(' ')

plt.show()

# %%
df2_factors_unhap = df2[-10:].groupby('Country name').sum()[['Social support','Freedom to make life choices','Generosity','Perceptions of corruption']]

df2_factors_unhap
# Out:
#               Social support  Freedom to make life choices  Generosity  \
# Country name
# Afghanistan            0.463                         0.382      -0.102
# Botswana               0.784                         0.824      -0.246
# Burundi                0.490                         0.626      -0.024
# Haiti                  0.540                         0.593       0.422
# Lesotho                0.787                         0.715      -0.131
# Malawi                 0.537                         0.780       0.038
# Rwanda                 0.552                         0.897       0.061
# Tanzania               0.702                         0.833       0.183
# Yemen                  0.832                         0.602      -0.147
# Zimbabwe               0.750                         0.677      -0.047
#
#               Perceptions of corruption
# Country name
# Afghanistan                       0.924
# Botswana                          0.801
# ...

# %%
df2_factors_unhap.plot(kind='bar', fontsize = 22)
plt.title('Factors that contribute to Unhappiness', fontsize = 22)
plt.legend(loc="upper right", bbox_to_anchor=(1.8, 1.03), ncol=2, fontsize = 20)
plt.ylabel(' ')

plt.show()

# %%
top10_hap_HLE = df2.loc[:10, ['Country name','Healthy life expectancy']]
column = ['Country name','Healthy life expectancy']
top10_unhap_HLE = df2.loc[:, column].tail(10)
topbottom_HLE = top10_hap_HLE.append(top10_unhap_HLE)

# %%
topbottom_HLE
# Out:
#     Country name  Healthy life expectancy
# 0        Finland                   72.000
# 1        Denmark                   72.700
# 2    Switzerland                   74.400
# 3        Iceland                   73.000
# 4    Netherlands                   72.400
# 5         Norway                   73.300
# 6         Sweden                   72.700
# 7     Luxembourg                   72.600
# 8    New Zealand                   73.400
# 9        Austria                   73.300
# 10     Australia                   73.900
# 139      Burundi                   53.400
# 140        Yemen                   57.122
# 141     Tanzania                   57.999
# 142        Haiti                   55.700
# 143       Malawi                   57.948
# 144      Lesotho                   48.700
# 145     Botswana                   59.269
# 146       Rwanda                   61.400
# 147     Zimbabwe                   56.201
# 148  Afghanistan                   52.493

# %%
ax = topbottom_HLE.plot.bar(x='Country name', y='Healthy life expectancy',color = 'purple')

# %% [markdown]
# Life expectancy is significantly different between the top 10 happy and unhappy countries.

# %% [markdown]
# ## Importan Factors
# 1. The factors that played the most role in the happy countries was social support and the freedom to make life choices
# 2. The factors that played the most role in the unhappy countries was perception of corruption being high along with social support being below average for most countries

# %%
# Healthy life expectancy is the biggest because it has the highest values compared to the other variables
# Comparing healthy life expetancy between top 10 happiest vs top 10 unhappiest we can see that there is a correlation between happiness and life expectancy
# Im going to make a Correlation graph all other parameters besides life expectancy

# %%
df3 = df2[["Country name","Ladder score","Social support","Freedom to make life choices","Generosity","Perceptions of corruption",]]

# %%
import matplotlib.gridspec as gs
color=["#f94144","#f3722c","#f8961e","#f9c74f","#90be6d","#43aa8b","#577590"]
cols=df3.corr()['Ladder score'].sort_values(ascending=False)

# %%
def country_comp1(country1, country2):
    df4=df3[df3['Country name'].isin([country1, country2])]
    df4=df4[cols.index].T
    df4.columns=[country1,country2]
    print(df4)
    fig = plt.figure(figsize=(15,10))
    plt.suptitle("Comparison {} and {}".format(country1, country2),family='Serif', weight='bold', size=20)
    g=gs.GridSpec(nrows=1, ncols=2, wspace=0)
    ax1=plt.subplot(g[0,0])
    for s in ['left','right','top','bottom']:
        ax1.spines[s].set_visible(False)
   
    #ax1.set_xlim(xmin=0)
    ax1=sns.barplot(data=df4,y=df4.index,x=country1, color=color[-1]).invert_xaxis()
    
    ax2=plt.subplot(g[0,1], sharey=ax1)
    ax2=sns.barplot(data=df4,y=df4.index,x=country2, color=color[-2])
    #ax2.set_xlim(xmin=0)
    ax2.yaxis.tick_right()
    for s in ['left','right','top','bottom']:
        ax2.spines[s].set_visible(False)
    return

# %%
country_comp1('Finland','Afghanistan')
# Out:
#                               Finland  Afghanistan
# Ladder score                    7.842        2.523
# Social support                  0.954        0.463
# Freedom to make life choices    0.949        0.382
# Generosity                     -0.098       -0.102
# Perceptions of corruption       0.186        0.924

# %% [markdown]
# ## Anwser Questions
# ## 1. Which country is the most happiest?
# After comparing ladder scores, it was found that the happiest country is Finland. We used the ladder scores to do this analysis because it gives an overall score and rating based on the other factors of which country is the happiest.
#
# ## 2. Which country is the least Happiest?
# After comparing the ladder scores it was found that Afghanistan was the least happiest country.
#
# ## 3. Which country is the happiest based on capita?
# I also compared Iceland, which has the lowest population, to China, which has the highest population. The results showed the same variables playing a part in why a country may be happier.
#
# ## 4. Which factors most effects happiness?
# After completing this analysis and comparing Finland to Afghanistan, it was found that the factors that contributed to the happiness success of Finland was freedom to make life choices, social support, and the preception of corruption was low. These inturn resulted in a higher life expectancy.
#
# ## 5. Which factors least contribute to happiness?
# From the data we can see that genoristy did not play a big role in if a country was happpier or not.

# %% [markdown]
# # Summary and Conclusion
#
# In conclusion this data was able to show us with country is the happiest and for what reason. We were able to see tha Finland was the happiest country for having the freedom to make life choices, social support and having their percetion of corruption being low. Afghanistan was the unhappiest for the same reasons but the the scores being lower. They do not have the freedom to make life choices, low social support, and their perception of corruption is high. Furthermore I think this data can be further analyzed to see if low stress is a factor in the life expectancy being so high. the top countries have a higher life expectancy than the bottom 10 so it would be interesting to see if stress, a wrose economy or another factor plays a role in why this is true. For example for the healhty life expectancy can the age difference be because of people being less happy or can it be because there is more poverty and less health care in those countries.

# %%
color={}
color_list=['#FF0000','#00FF00','#0000FF','#FFFF00','#00FFFF','#FF00FF','#808080','#800000','#808000','#008000']
i=0
for c in top10:
    color[c]=color_list[i]
    i+=1
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-49-e1b5a1b00aca> in <module>
#       2 color_list=['#FF0000','#00FF00','#0000FF','#FFFF00','#00FFFF','#FF00FF','#808080','#800000','#808000','#008000']
#       3 i=0
# ----> 4 for c in top10:
#       5     color[c]=color_list[i]
#       6     i+=1
#
# NameError: name 'top10' is not defined
